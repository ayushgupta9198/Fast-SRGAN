# %%
cd /content/drive/My Drive/Ayush Gupta/ Fast-SRGAN/Fast-SRGAN
# Out:
# /content/drive/My Drive/Ayush Gupta/ Fast-SRGAN/Fast-SRGAN

# %%
# !pip3 install -r requirements.txt

# %%
# !python infer.py --image_dir './maomao_kobe_TO_asakuranozomi/' --output_dir './output-maomao_kobe_TO_asakuranozomi/'
# Out:
# 2020-09-16 06:22:05.340688: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...
